# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
# fc-list | grep "NanumGothic.ttf" 로 정확한 경로 확인
# 예: /usr/share/fonts/truetype/nanum/NanumGothic.ttf

# 정확한 경로를 직접 지정
font_path = '/usr/share/fonts/nanum/NanumGothic.ttf'
font_prop = fm.FontProperties(fname=font_path)
font_name = font_prop.get_name()

plt.rc('font', family=font_name)
plt.rcParams['axes.unicode_minus'] = False

print(f"폰트 설정 완료: {font_name}")

# 테스트 플롯
plt.figure()
plt.plot([1, 2, 3], [4, 5, 6])
plt.title('한글 제목 테스트')
plt.xlabel('X축 라벨')
plt.ylabel('Y축 라벨')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 7
#       5 font_path = '/usr/share/fonts/nanum/NanumGothic.ttf'
#       6 font_prop = fm.FontProperties(fname=font_path)
# ----> 7 font_name = font_prop.get_name()
#       9 plt.rc('font', family=font_name)
#      10 plt.rcParams['axes.unicode_minus'] = False
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/font_manager.py:731, in FontProperties.get_name(self)
#     727 def get_name(self):
#     728     """
#     729     Return the name of the font that best matches the font properties.
#     730     """
# --> 731     return get_font(findfont(self)).family_name
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/font_manager.py:1615, in get_font(font_filepaths, hinting_factor)
#    1612 if hinting_factor is None:
#    1613     hinting_factor = mpl.rcParams['text.hinting_factor']
# ...

# %%
# 기존에 한글 폰트를 설정하는 코드 바로 아래에 추가합니다.
plt.rc('font', family='NanumGothic') # 또는 다른 설정된 한글 폰트 이름
plt.rcParams['axes.unicode_minus'] = False

# --- 바로 이 부분입니다 ---
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42 # PostScript(ps) 파일도 동일하게 설정
# -------------------------

# 이제 PDF로 저장하면 한글이 깨지지 않습니다.
plt.figure()
plt.title('PDF 저장용 한글 제목 테스트')
plt.xlabel('X축')
plt.ylabel('Y축')
plt.plot([1,2,3], [10,20,15])

plt.savefig('korean_report.pdf')
print("PDF 저장 완료: korean_report.pdf")
# Out:
# PDF 저장 완료: korean_report.pdf
